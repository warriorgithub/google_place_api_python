# %%
import requests, json 
import time
import sys
y=[]
# enter your api key here 
api_key = 'AIzaSyDA3_VPtYxSqbu0BGIvPxBYCYX77oMfGHM'


print('Search query: ')
#query = input() 
#'Anand Lok','Anand Niketan,'Chittranjan Park','Chirag Enclave','Defence Colony','East of Kailash','Friends Colony East',
# 'Friends Colony West','Geetanjali Enclave','Greater Kailash','Gulmohar Park','Hemkunt Colony','Hauz Khas','Hauz Khas Enclave','Jangpura Extension','Jor Bagh',
#'Kailash Colony','Kailash Hills','Lajpat Nagar','Maharani Bagh','Malviya Nagar','New Friends Colony','Nizamuddin East',
#'Nizamuddin West','Navjivan Vihar','Panchsheel Enclave',


south_delhi = ['Panchsheel Park','Pamposh Enclave','Safdarjung Enclave',
'Safdarjung Developmental Area','Sarvapriya Vihar','Uday Park','Vasant Vihar','Westend']



for place in south_delhi:
    url = "https://maps.googleapis.com/maps/api/place/textsearch/json?"
    place = 'hostel and pg in '+ place +' south delhi '
    print('start searching for ',place)

    r = requests.get(url + 'query=' + place +'&radius=500000'+
                            '&key=' + api_key)
    x = r.json() 
    #print('results',x['results'])
    y.extend(x['results']) 
    time.sleep(10)
    count=0;
    while "next_page_token" in x:
        next_page = x['next_page_token']
        #print(count, '    ',next_page)
        r = requests.get(url + 'query=' + place + '&radius=50000'+
                            '&key=' + api_key +'&pagetoken='+next_page)
        x = r.json()
        #print('next_page_token for ',place)
        y.extend(x['results'])
    if(len(y)>0):
        for i in range(len(y)): 
            place_id = y[i]['place_id']
            print('Place id for',y[i]['name']+'-----> '  ,place_id)
            time.sleep(60)
            try:
                url = "https://maps.googleapis.com/maps/api/place/details/json?"


                req = requests.get(url + 'place_id=' + place_id +
                                        '&key=' + api_key + '&fields=formatted_phone_number,url') 
                xa = req.json() 
                
                
                ya = xa['result']
                #print('name ',y[i]['name'])
                #print('address ',y[i]['formatted_address'])
                #print('phone ',ya['formatted_phone_number'])
                #print('url ',ya['url'])
                name=''
                address=''
                phone_number=''
                url=''
                print('starting if condi')
                if None!=y[i]['name'] and y[i]['name']!='':
                    name = y[i]['name']
                    #print(name)
                if None!=y[i]['formatted_address'] and y[i]['formatted_address']!='':
                    address = y[i]['formatted_address']
                    #print(address)
                if None!=ya['formatted_phone_number'] and ya['formatted_phone_number']!='':    
                    phone_number = ya['formatted_phone_number']
                    #print(phone_number)
                if None!=ya['url'] and ya['url']!='':
                    url = ya['url']
                    #print(url)
                    
                res = str(name)+" | "+str(address)+" | "+str(phone_number)+" | "+str(url)+' \n '
                
                print('Response parameter', res)
                #res_str = convertTuple(res)
                #file2 = open("contect.txt","a") 
                #file2.write(res)
            except :
                print('exception................',sys.exc_info()[0])
                continue
    else:
        print('No result found in  ',place)
# Out:
# Search query:
# start searching for  hostel and pg in Lajpat Nagar south delhi
# Place id for Boys PG in lajpat nagar----->  ChIJq6qqvrPjDDkR671W4QgO-ck
# starting if condi
# Response parameter Boys PG in lajpat nagar | B-171, near Moolchand Metro Station, National Park, Lajpat Nagar 4, New Delhi, Delhi 110024, India | 095997 61522 | https://maps.google.com/?cid=14553679102127554027
#
# start searching for  hostel and pg in Maharani Bagh south delhi
# Place id for Boys PG in lajpat nagar----->  ChIJq6qqvrPjDDkR671W4QgO-ck
# starting if condi
# Response parameter Boys PG in lajpat nagar | B-171, near Moolchand Metro Station, National Park, Lajpat Nagar 4, New Delhi, Delhi 110024, India | 095997 61522 | https://maps.google.com/?cid=14553679102127554027
#
# Place id for Ravi PG Hostel----->  ChIJq6qqqrPjDDkRZkfAIv-L5ko
# starting if condi
# ...

# %%
res= str('name')+" | "+str('address')+" | "+str('phone_number')+" | "+str('url')+' \n '
print(convertTuple(res))

# %%
def convertTuple(res):
    res = "".join(res)
    return res

# %%
south_delhi = ['Friends Colony West',
'Geetanjali Enclave','Greater Kailash','Gulmohar Park','Hemkunt Colony','Hauz Khas','Hauz Khas Enclave','Jangpura Extension','Jor Bagh',
'Kailash Colony','Kailash Hills','Lajpat Nagar','Maharani Bagh','Malviya Nagar','New Friends Colony','Nizamuddin East',
'Nizamuddin West','Navjivan Vihar','Panchsheel Enclave','Panchsheel Park','Pamposh Enclave','Safdarjung Enclave',
'SDA (Safdarjung Developmental Area)','Sarvapriya Vihar','Uday Park','Vasant Vihar','Westend']
for i in south_delhi:
    print(i)
# Out:
# Friends Colony West
# Geetanjali Enclave
# Greater Kailash
# Gulmohar Park
# Hemkunt Colony
# Hauz Khas
# Hauz Khas Enclave
# Jangpura Extension
# Jor Bagh
# Kailash Colony
# Kailash Hills
# Lajpat Nagar
# Maharani Bagh
# Malviya Nagar
# New Friends Colony
# Nizamuddin East
# Nizamuddin West
# Navjivan Vihar
# Panchsheel Enclave
# Panchsheel Park
# Pamposh Enclave
# Safdarjung Enclave
# SDA (Safdarjung Developmental Area)
# Sarvapriya Vihar
# Uday Park
# Vasant Vihar
# Westend

# %%
import pandas as pd

# %%
data = pd.read_csv('output.csv', sep="|",header=None)
data.column('name','address','phone_number','url')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-feb347dce3a3> in <module>
# ----> 1 data = pd.read_csv('output.csv', sep="|",header=None)
#       2 data.column('name','address','phone_number','url')
#
# NameError: name 'pd' is not defined
